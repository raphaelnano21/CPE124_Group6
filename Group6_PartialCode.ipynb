# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting spacy
#   Downloading spacy-3.7.2-cp310-cp310-win_amd64.whl (12.1 MB)
#      ---------------------------------------- 12.1/12.1 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Collecting thinc<8.3.0,>=8.1.8
#   Downloading thinc-8.2.2-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 4.5 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp310-cp310-win_amd64.whl (25 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp310-cp310-win_amd64.whl (39 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp310-cp310-win_amd64.whl (122 kB)
#      -------------------------------------- 122.2/122.2 kB 7.5 MB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting typer<0.10.0,>=0.3.0
#   Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Using cached pydantic-2.5.3-py3-none-any.whl (381 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (22.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting weasel<0.4.0,>=0.1.0
#   Using cached weasel-0.3.4-py3-none-any.whl (50 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp310-cp310-win_amd64.whl (481 kB)
#      -------------------------------------- 481.9/481.9 kB 5.0 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.14.6
#   Downloading pydantic_core-2.14.6-cp310-none-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 4.3 MB/s eta 0:00:00
# Collecting typing-extensions>=4.6.1
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.1.4-py3-none-any.whl (35 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp310-cp310-win_amd64.whl (6.6 MB)
#      ---------------------------------------- 6.6/6.6 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Collecting cloudpathlib<0.17.0,>=0.7.0
#   Using cached cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: cymem, wasabi, typing-extensions, spacy-loggers, spacy-legacy, murmurhash, langcodes, catalogue, blis, annotated-types, typer, srsly, pydantic-core, preshed, cloudpathlib, pydantic, confection, weasel, thinc, spacy
# Successfully installed annotated-types-0.6.0 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.5.3 pydantic-core-2.14.6 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.2 typer-0.9.0 typing-extensions-4.9.0 wasabi-1.1.2 weasel-0.3.4
#   WARNING: The script weasel.exe is installed in 'C:\Users\Raphael Nano\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy.exe is installed in 'C:\Users\Raphael Nano\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 12.8/12.8 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.23.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.64.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (22.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.28.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.3)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.6)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\raphael nano\appdata\roaming\python\python310\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
with open ("symptoms.txt", "r") as f:
    text = f.read()

# %%
print (text)
# Out:
# Cellulitis manifests through various symptoms that can signal its presence. Individuals may experience fever accompanied by chills and sweating, along with an overarching sense of fatigue. The affected area typically becomes painful or tender to the touch, often showing signs of skin redness or inflammation that gradually expands as the infection progresses. This redness might evolve into a sore or rash, appearing suddenly and rapidly intensifying within the initial 24 hours. The skin might take on a tight, glossy, stretched appearance, accompanied by warmth in the infected region. Additionally, due to tissue swelling over joints, muscle aches and joint stiffness might arise, contributing to discomfort. Some individuals may also experience nausea and vomiting as part of the overall symptoms of cellulitis.
#
#
# Impetigo, a contagious skin infection, presents several distinct symptoms. These include the appearance of red sores that quickly rupture, ooze, and form honey-colored crusts. These sores commonly occur around the mouth and nose but can surface anywhere on the body. They're often itchy and may spread rapidly, leading to more sores. Swollen lymph nodes in the affected area might also accompany these skin lesions. In some cases, a fever could accompany these symptoms, but it's not as common.
#
# Athlete's foot, a fungal infection of the skin on the feet, typically showcases several noticeable symptoms. These include itching, stinging, or burning sensations, especially between the toes or on the soles of the feet. The affected skin might appear red, cracked, or scaly, with potential for peeling or flaking. In severe cases, blisters and ulcers could form, causing pain and discomfort. Additionally, some individuals might experience a raw skin sensation or a mild odor emanating from the infected area.
#
#
# Nail fungus, medically known as onychomycosis, often manifests with distinctive symptoms. Initially, it might appear as a white or yellow spot under the tip of the nail. As the infection progresses, the nail can become discolored, thickened, and brittle. It might develop a crumbly texture or even detach from the nail bed, leading to pain and discomfort. In advanced cases, the infected nail might emit a foul odor, and there could be slight swelling around the nail area. If left untreated, the infection can spread to other nails, causing further discoloration and deformities.
#
#
# Ringworm, despite its name, is not caused by a worm but by a fungus that affects the skin. The symptoms of ringworm include a red or silver rash that appears in a circular or ring-shaped pattern, hence the name. This rash might be itchy, scaly, or raised, and it often has a defined border. It can occur on various parts of the body, such as the scalp, feet (athlete's foot), groin area (jock itch), or other skin areas. In some cases, multiple rings might develop, and the affected skin might show signs of inflammation. Additionally, hair loss might occur in areas affected by ringworm of the scalp.
#
# Cutaneous larva migrans is a skin condition caused by hookworm larvae that typically infest tropical and subtropical areas. The primary symptom is the appearance of an itchy, winding, raised rash on the skin, resembling tracks or serpentine lines. These lines are where the larvae have migrated under the skin, and they can be red, raised, and intensely itchy. The rash may progress, changing its appearance as the larvae continue to move beneath the skin, causing discomfort and irritation. Other symptoms might include a burning sensation, swelling, or the formation of blisters along the tracks of the larvae.
#
# Chickenpox, caused by the varicella-zoster virus, typically starts with symptoms similar to a mild flu, followed by the characteristic rash. Initially, individuals might experience a fever, headache, fatigue, and loss of appetite. Within a day or two, a red, itchy rash appears, starting on the face, chest, and back before spreading to other parts of the body. The rash develops into small, fluid-filled blisters that eventually crust over and scab. These blisters can be at different stages of healing simultaneously. Alongside the rash, individuals might also experience sore throat, cough, abdominal pain, and in some cases, the blisters can cause mild to moderate itching and discomfort.
#
# Shingles, caused by the reactivation of the varicella-zoster virus (the same virus that causes chickenpox), typically presents as a painful, blistering rash. Prior to the rash's appearance, individuals might experience tingling, itching, or burning sensations in a specific area of the skin. This is often followed by a red, painful rash that forms small, fluid-filled blisters, commonly occurring in a band or stripe on one side of the body or face. The rash can be accompanied by fever, headache, fatigue, and sensitivity to light. The blisters typically crust over within a week to ten days and gradually heal, but some individuals might experience persistent pain, known as postherpetic neuralgia, in the affected area for months or even years after the rash has healed.

# %%
doc = nlp (text)

# %%
for token in doc:
    print(token.text)
# Out:
# Cellulitis
# manifests
# through
# various
# symptoms
# that
# can
# signal
# its
# presence
# .
# Individuals
# may
# experience
# fever
# accompanied
# by
# chills
# and
# sweating
# ,
# along
# with
# an
# overarching
# sense
# of
# fatigue
# .
# The
# affected
# area
# typically
# becomes
# painful
# or
# tender
# to
# the
# touch
# ,
# often
# showing
# signs
# of
# skin
# redness
# or
# inflammation
# that
# gradually
# expands
# as
# the
# infection
# progresses
# .
# This
# redness
# might
# evolve
# into
# a
# sore
# or
# rash
# ,
# appearing
# suddenly
# and
# rapidly
# intensifying
# within
# the
# initial
# 24
# hours
# .
# The
# skin
# might
# take
# on
# a
# tight
# ,
# glossy
# ,
# stretched
# appearance
# ,
# accompanied
# by
# warmth
# in
# the
# infected
# region
# .
# Additionally
# ,
# due
# to
# tissue
# swelling
# over
# joints
# ,
# muscle
# aches
# and
# joint
# stiffness
# might
# arise
# ,
# contributing
# to
# discomfort
# .
# Some
# individuals
# may
# also
# experience
# nausea
# and
# vomiting
# as
# part
# of
# the
# overall
# symptoms
# of
# cellulitis
# .
#
#
#
#
# Impetigo
# ,
# a
# contagious
# skin
# infection
# ,
# presents
# several
# distinct
# symptoms
# .
# These
# include
# the
# appearance
# of
# red
# sores
# that
# quickly
# rupture
# ,
# ooze
# ,
# and
# form
# honey
# -
# colored
# crusts
# .
# These
# sores
# commonly
# occur
# around
# the
# mouth
# and
# nose
# but
# can
# surface
# anywhere
# on
# the
# body
# .
# They
# 're
# often
# itchy
# and
# may
# spread
# rapidly
# ,
# leading
# to
# more
# sores
# .
# Swollen
# lymph
# nodes
# in
# the
# affected
# area
# might
# also
# accompany
# these
# skin
# lesions
# .
# In
# some
# cases
# ,
# a
# fever
# could
# accompany
# these
# symptoms
# ,
# but
# it
# 's
# not
# as
# common
# .
#
#
#
# Athlete
# 's
# foot
# ,
# a
# fungal
# infection
# of
# the
# skin
# on
# the
# feet
# ,
# typically
# showcases
# several
# noticeable
# symptoms
# .
# These
# include
# itching
# ,
# stinging
# ,
# or
# burning
# sensations
# ,
# especially
# between
# the
# toes
# or
# on
# the
# soles
# of
# the
# feet
# .
# The
# affected
# skin
# might
# appear
# red
# ,
# cracked
# ,
# or
# scaly
# ,
# with
# potential
# for
# peeling
# or
# flaking
# .
# In
# severe
# cases
# ,
# blisters
# and
# ulcers
# could
# form
# ,
# causing
# pain
# and
# discomfort
# .
# Additionally
# ,
# some
# individuals
# might
# experience
# a
# raw
# skin
# sensation
# or
# a
# mild
# odor
# emanating
# from
# the
# infected
# area
# .
#
#
#
#
# Nail
# fungus
# ,
# medically
# known
# as
# onychomycosis
# ,
# often
# manifests
# with
# distinctive
# symptoms
# .
# Initially
# ,
# it
# might
# appear
# as
# a
# white
# or
# yellow
# spot
# under
# the
# tip
# of
# the
# nail
# .
# As
# the
# infection
# progresses
# ,
# the
# nail
# can
# become
# discolored
# ,
# thickened
# ,
# and
# brittle
# .
# It
# might
# develop
# a
# crumbly
# texture
# or
# even
# detach
# from
# the
# nail
# bed
# ,
# leading
# to
# pain
# and
# discomfort
# .
# In
# advanced
# cases
# ,
# the
# infected
# nail
# might
# emit
# a
# foul
# odor
# ,
# and
# there
# could
# be
# slight
# swelling
# around
# the
# nail
# area
# .
# If
# left
# untreated
# ,
# the
# infection
# can
# spread
# to
# other
# nails
# ,
# causing
# further
# discoloration
# and
# deformities
# .
#
#
#
#
# Ringworm
# ,
# despite
# its
# name
# ,
# is
# not
# caused
# by
# a
# worm
# but
# by
# a
# fungus
# that
# affects
# the
# skin
# .
# The
# symptoms
# of
# ringworm
# include
# a
# red
# or
# silver
# rash
# that
# appears
# in
# a
# circular
# or
# ring
# -
# shaped
# pattern
# ,
# hence
# the
# name
# .
# This
# rash
# might
# be
# itchy
# ,
# scaly
# ,
# or
# raised
# ,
# and
# it
# often
# has
# a
# defined
# border
# .
# It
# can
# occur
# on
# various
# parts
# of
# the
# body
# ,
# such
# as
# the
# scalp
# ,
# feet
# (
# athlete
# 's
# foot
# )
# ,
# groin
# area
# (
# jock
# itch
# )
# ,
# or
# other
# skin
# areas
# .
# In
# some
# cases
# ,
# multiple
# rings
# might
# develop
# ,
# and
# the
# affected
# skin
# might
# show
# signs
# of
# inflammation
# .
# Additionally
# ,
# hair
# loss
# might
# occur
# in
# areas
# affected
# by
# ringworm
# of
# the
# scalp
# .
#
#
#
# Cutaneous
# larva
# migrans
# is
# a
# skin
# condition
# caused
# by
# hookworm
# larvae
# that
# typically
# infest
# tropical
# and
# subtropical
# areas
# .
# The
# primary
# symptom
# is
# the
# appearance
# of
# an
# itchy
# ,
# winding
# ,
# raised
# rash
# on
# the
# skin
# ,
# resembling
# tracks
# or
# serpentine
# lines
# .
# These
# lines
# are
# where
# the
# larvae
# have
# migrated
# under
# the
# skin
# ,
# and
# they
# can
# be
# red
# ,
# raised
# ,
# and
# intensely
# itchy
# .
# The
# rash
# may
# progress
# ,
# changing
# its
# appearance
# as
# the
# larvae
# continue
# to
# move
# beneath
# the
# skin
# ,
# causing
# discomfort
# and
# irritation
# .
# Other
# symptoms
# might
# include
# a
# burning
# sensation
# ,
# swelling
# ,
# or
# the
# formation
# of
# blisters
# along
# the
# tracks
# of
# the
# larvae
# .
#
#
#
# Chickenpox
# ,
# caused
# by
# the
# varicella
# -
# zoster
# virus
# ,
# typically
# starts
# with
# symptoms
# similar
# to
# a
# mild
# flu
# ,
# followed
# by
# the
# characteristic
# rash
# .
# Initially
# ,
# individuals
# might
# experience
# a
# fever
# ,
# headache
# ,
# fatigue
# ,
# and
# loss
# of
# appetite
# .
# Within
# a
# day
# or
# two
# ,
# a
# red
# ,
# itchy
# rash
# appears
# ,
# starting
# on
# the
# face
# ,
# chest
# ,
# and
# back
# before
# spreading
# to
# other
# parts
# of
# the
# body
# .
# The
# rash
# develops
# into
# small
# ,
# fluid
# -
# filled
# blisters
# that
# eventually
# crust
# over
# and
# scab
# .
# These
# blisters
# can
# be
# at
# different
# stages
# of
# healing
# simultaneously
# .
# Alongside
# the
# rash
# ,
# individuals
# might
# also
# experience
# sore
# throat
# ,
# cough
# ,
# abdominal
# pain
# ,
# and
# in
# some
# cases
# ,
# the
# blisters
# can
# cause
# mild
# to
# moderate
# itching
# and
# discomfort
# .
#
#
#
# Shingles
# ,
# caused
# by
# the
# reactivation
# of
# the
# varicella
# -
# zoster
# virus
# (
# the
# same
# virus
# that
# causes
# chickenpox
# )
# ,
# typically
# presents
# as
# a
# painful
# ,
# blistering
# rash
# .
# Prior
# to
# the
# rash
# 's
# appearance
# ,
# individuals
# might
# experience
# tingling
# ,
# itching
# ,
# or
# burning
# sensations
# in
# a
# specific
# area
# of
# the
# skin
# .
# This
# is
# often
# followed
# by
# a
# red
# ,
# painful
# rash
# that
# forms
# small
# ,
# fluid
# -
# filled
# blisters
# ,
# commonly
# occurring
# in
# a
# band
# or
# stripe
# on
# one
# side
# of
# the
# body
# or
# face
# .
# The
# rash
# can
# be
# accompanied
# by
# fever
# ,
# headache
# ,
# fatigue
# ,
# and
# sensitivity
# to
# light
# .
# The
# blisters
# typically
# crust
# over
# within
# a
# week
# to
# ten
# days
# and
# gradually
# heal
# ,
# but
# some
# individuals
# might
# experience
# persistent
# pain
# ,
# known
# as
# postherpetic
# neuralgia
# ,
# in
# the
# affected
# area
# for
# months
# or
# even
# years
# after
# the
# rash
# has
# healed
# .

# %%
filtered_tokens = [token.text for token in doc if not token.is_stop]
print(filtered_tokens)
# Out:
# ['Cellulitis', 'manifests', 'symptoms', 'signal', 'presence', '.', 'Individuals', 'experience', 'fever', 'accompanied', 'chills', 'sweating', ',', 'overarching', 'sense', 'fatigue', '.', 'affected', 'area', 'typically', 'painful', 'tender', 'touch', ',', 'showing', 'signs', 'skin', 'redness', 'inflammation', 'gradually', 'expands', 'infection', 'progresses', '.', 'redness', 'evolve', 'sore', 'rash', ',', 'appearing', 'suddenly', 'rapidly', 'intensifying', 'initial', '24', 'hours', '.', 'skin', 'tight', ',', 'glossy', ',', 'stretched', 'appearance', ',', 'accompanied', 'warmth', 'infected', 'region', '.', 'Additionally', ',', 'tissue', 'swelling', 'joints', ',', 'muscle', 'aches', 'joint', 'stiffness', 'arise', ',', 'contributing', 'discomfort', '.', 'individuals', 'experience', 'nausea', 'vomiting', 'overall', 'symptoms', 'cellulitis', '.', '\n\n\n', 'Impetigo', ',', 'contagious', 'skin', 'infection', ',', 'presents', 'distinct', 'symptoms', '.', 'include', 'appearance', 'red', 'sores', 'quickly', 'rupture', ',', 'ooze', ',', 'form', 'honey', '-', 'colored', 'crusts', '.', 'sores', 'commonly', 'occur', 'mouth', 'nose', 'surface', 'body', '.', 'itchy', 'spread', 'rapidly', ',', 'leading', 'sores', '.', 'Swollen', 'lymph', 'nodes', 'affected', 'area', 'accompany', 'skin', 'lesions', '.', 'cases', ',', 'fever', 'accompany', 'symptoms', ',', 'common', '.', '\n\n', 'Athlete', 'foot', ',', 'fungal', 'infection', 'skin', 'feet', ',', 'typically', 'showcases', 'noticeable', 'symptoms', '.', 'include', 'itching', ',', 'stinging', ',', 'burning', 'sensations', ',', 'especially', 'toes', 'soles', 'feet', '.', 'affected', 'skin', 'appear', 'red', ',', 'cracked', ',', 'scaly', ',', 'potential', 'peeling', 'flaking', '.', 'severe', 'cases', ',', 'blisters', 'ulcers', 'form', ',', 'causing', 'pain', 'discomfort', '.', 'Additionally', ',', 'individuals', 'experience', 'raw', 'skin', 'sensation', 'mild', 'odor', 'emanating', 'infected', 'area', '.', '\n\n\n', 'Nail', 'fungus', ',', 'medically', 'known', 'onychomycosis', ',', 'manifests', 'distinctive', 'symptoms', '.', 'Initially', ',', 'appear', 'white', 'yellow', 'spot', 'tip', 'nail', '.', 'infection', 'progresses', ',', 'nail', 'discolored', ',', 'thickened', ',', 'brittle', '.', 'develop', 'crumbly', 'texture', 'detach', 'nail', 'bed', ',', 'leading', 'pain', 'discomfort', '.', 'advanced', 'cases', ',', 'infected', 'nail', 'emit', 'foul', 'odor', ',', 'slight', 'swelling', 'nail', 'area', '.', 'left', 'untreated', ',', 'infection', 'spread', 'nails', ',', 'causing', 'discoloration', 'deformities', '.', '\n\n\n', 'Ringworm', ',', 'despite', ',', 'caused', 'worm', 'fungus', 'affects', 'skin', '.', 'symptoms', 'ringworm', 'include', 'red', 'silver', 'rash', 'appears', 'circular', 'ring', '-', 'shaped', 'pattern', ',', '.', 'rash', 'itchy', ',', 'scaly', ',', 'raised', ',', 'defined', 'border', '.', 'occur', 'parts', 'body', ',', 'scalp', ',', 'feet', '(', 'athlete', 'foot', ')', ',', 'groin', 'area', '(', 'jock', 'itch', ')', ',', 'skin', 'areas', '.', 'cases', ',', 'multiple', 'rings', 'develop', ',', 'affected', 'skin', 'signs', 'inflammation', '.', 'Additionally', ',', 'hair', 'loss', 'occur', 'areas', 'affected', 'ringworm', 'scalp', '.', '\n\n', 'Cutaneous', 'larva', 'migrans', 'skin', 'condition', 'caused', 'hookworm', 'larvae', 'typically', 'infest', 'tropical', 'subtropical', 'areas', '.', 'primary', 'symptom', 'appearance', 'itchy', ',', 'winding', ',', 'raised', 'rash', 'skin', ',', 'resembling', 'tracks', 'serpentine', 'lines', '.', 'lines', 'larvae', 'migrated', 'skin', ',', 'red', ',', 'raised', ',', 'intensely', 'itchy', '.', 'rash', 'progress', ',', 'changing', 'appearance', 'larvae', 'continue', 'beneath', 'skin', ',', 'causing', 'discomfort', 'irritation', '.', 'symptoms', 'include', 'burning', 'sensation', ',', 'swelling', ',', 'formation', 'blisters', 'tracks', 'larvae', '.', '\n\n', 'Chickenpox', ',', 'caused', 'varicella', '-', 'zoster', 'virus', ',', 'typically', 'start ...

# %%
lemmatized_text = " ".join([token.lemma_ for token in doc])
print(lemmatized_text)
# Out:
# cellulitis manifest through various symptom that can signal its presence . individual may experience fever accompany by chill and sweating , along with an overarching sense of fatigue . the affected area typically become painful or tender to the touch , often show sign of skin redness or inflammation that gradually expand as the infection progress . this redness might evolve into a sore or rash , appear suddenly and rapidly intensify within the initial 24 hour . the skin might take on a tight , glossy , stretch appearance , accompany by warmth in the infected region . additionally , due to tissue swell over joint , muscle ache and joint stiffness might arise , contribute to discomfort . some individual may also experience nausea and vomit as part of the overall symptom of cellulitis .
#
#
#  Impetigo , a contagious skin infection , present several distinct symptom . these include the appearance of red sore that quickly rupture , ooze , and form honey - color crust . these sore commonly occur around the mouth and nose but can surface anywhere on the body . they be often itchy and may spread rapidly , lead to more sore . swollen lymph node in the affected area might also accompany these skin lesion . in some case , a fever could accompany these symptom , but it be not as common .
#
#  Athlete 's foot , a fungal infection of the skin on the foot , typically showcase several noticeable symptom . these include itching , stinging , or burn sensation , especially between the toe or on the sol of the foot . the affected skin might appear red , crack , or scaly , with potential for peel or flaking . in severe case , blister and ulcer could form , cause pain and discomfort . additionally , some individual might experience a raw skin sensation or a mild odor emanating from the infected area .
#
#
#  Nail fungus , medically know as onychomycosis , often manifest with distinctive symptom . initially , it might appear as a white or yellow spot under the tip of the nail . as the infection progress , the nail can become discolor , thicken , and brittle . it might develop a crumbly texture or even detach from the nail bed , lead to pain and discomfort . in advanced case , the infected nail might emit a foul odor , and there could be slight swelling around the nail area . if leave untreated , the infection can spread to other nail , cause further discoloration and deformity .
#
#
#  Ringworm , despite its name , be not cause by a worm but by a fungus that affect the skin . the symptom of ringworm include a red or silver rash that appear in a circular or ring - shape pattern , hence the name . this rash might be itchy , scaly , or raise , and it often have a define border . it can occur on various part of the body , such as the scalp , foot ( athlete 's foot ) , groin area ( jock itch ) , or other skin area . in some case , multiple ring might develop , and the affected skin might show sign of inflammation . additionally , hair loss might occur in area affect by ringworm of the scalp .
#
#  cutaneous larva migrans be a skin condition cause by hookworm larvae that typically infest tropical and subtropical area . the primary symptom be the appearance of an itchy , winding , raise rash on the skin , resemble track or serpentine line . these line be where the larvae have migrate under the skin , and they can be red , raise , and intensely itchy . the rash may progress , change its appearance as the larvae continue to move beneath the skin , cause discomfort and irritation . other symptom might include a burn sensation , swelling , or the formation of blister along the track of the larvae .
#
#  Chickenpox , cause by the varicella - zoster virus , typically start with symptom similar to a mild flu , follow by the characteristic rash . initially , individual might experience a fever , headache , fatigue , and loss of appetite . within a day or two , a red , itchy rash appear , start on the face , chest , and back before spread to other part of the body . the rash develop into small , fluid - fill blister that eventually crust over and scab . these blister can be at different stage of healing simultaneously . alongside the rash , individual might also experience sore throat , cough , abdominal pain , and in some case , the blister can cause mild to moderate itching and discomfort .
#
#  shingle , cause by the reactivation of the varicella - zoster virus ( the same virus that cause chickenpox ) , typically present as a painful , blister rash . prior to the rash 's appearance , individual might experience tingling , itching , or burn sensation in a specific area of the skin . this be often follow by a red , painful rash that form small , fluid - fill blister , commonly occur in a band or stripe on one side of the body or face . the rash can be accompany by fever , headache , fatigue , and sensitivity to light . the blister typically crust over within a week to ten day and gradually heal , but some individual might experience persistent pain , know as postherpetic neuralgia , in the affected area for month or even year after the rash have heal .

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# the initial 24 hours TIME
# Athlete ORG
# feet PERSON
# migrans NORP
# a day DATE
# two CARDINAL
# Shingles PERSON
# one CARDINAL
# a week to ten days DATE
# neuralgia ORG
# months DATE
# years DATE
